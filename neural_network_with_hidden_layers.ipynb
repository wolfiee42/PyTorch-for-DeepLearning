# %% [markdown]
# <a href="https://colab.research.google.com/github/wolfiee42/PyTorch-for-DeepLearning/blob/main/neural_network_with_hidden_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(10, 18),
    nn.Linear(18, 20),
    nn.Linear(20, 5)
)

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=10, out_features=18, bias=True)
#   (1): Linear(in_features=18, out_features=20, bias=True)
#   (2): Linear(in_features=20, out_features=5, bias=True)
# )

# %%
import torch
import torch.nn as nn

model = nn.Sequential(
    nn.Linear(4, 8),
    nn.Linear(8, 2)
)

total_params = 0
for layer in model:
  total_params += layer.weight.numel() + layer.bias.numel()

  print(f"Total parameters: {total_params}")

total_params_2 = sum(p.numel() for p in model.parameters())
print(f"Total parameters 2: {total_params_2}")
# Out:
# Total parameters: 40
# Total parameters: 58
# Total parameters 2: 58

# %%
import torch
import torch.nn as nn

torch.manual_seed(42)

# Step 1: Create the model
model = nn.Sequential(
    nn.Linear(10, 18),
    nn.Linear(18, 20),
    nn.Linear(20, 5)
)


# Step 2: Create input data
input_data = torch.randn(3, 10)


# Step 3: Forward pass
output = model(input_data)


# Step 4: Count parameters
total_params = sum(p.numel() for p in model.parameters())


# Results
print("Model Architecture:")
print(model)
print(f"\nInput shape: {input_data.shape}")
print(f"Output shape: {output.shape}")
print(f"Total parameters: ", {total_params})
# Out:
# Model Architecture:
# Sequential(
#   (0): Linear(in_features=10, out_features=18, bias=True)
#   (1): Linear(in_features=18, out_features=20, bias=True)
#   (2): Linear(in_features=20, out_features=5, bias=True)
# )
#
# Input shape: torch.Size([3, 10])
# Output shape: torch.Size([3, 5])
# Total parameters:  {683}
